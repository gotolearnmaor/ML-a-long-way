# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("train.csv")

# %%
show = train[train["ship"] == 0]
plt.subplot(2,1,1)
plt.plot(show["v"])
plt.xlim((0, 450))
plt.ylim((-1, 10))
plt.subplot(2,1,2)
plt.plot(show["g"])
plt.xlim()
plt.ylim()
# Out:
# (-6.45, 135.45)

# %%
t = train[train['ship']==2963]
plt.plot(t['v'])

# %%
plt.plot(t["g"])

# %%
train['type'].unique()
# Out:
# array(['拖网', '围网', '刺网'], dtype=object)

# %%
def show_path(type_name):
    #找到相应类型的ID
    ids = train[train['type']==type_name]['ship'].unique()
    result = []
    for x in range(20):
        #随机生成渔船ID
        temp = ids[np.random.randint(len(ids))]
        result.append(temp)
    #布尔索引 找出渔船信息
    t = train[train['ship'].isin(result)]

    f, ax = plt.subplots(10,2, figsize=(8,20))
    for index, cur_id in enumerate(result):
        cur = t[t['ship']==cur_id]
        i = index//2
        j = index % 2
        ax[i,j].plot(cur['x'], cur['y'])
#         if i==0 and j==0:
        ax[i,j].set_title(cur_id)

# %%
show_path("围网")

# %%
show_path("围网")

# %%
show_path("刺网")

# %%
show_path("拖网")

# %%
data = train[train["渔船ID"] == 5000]

# %%
data.head()
# Out:
#          渔船ID             x             y    速度  方向             时间 渔船类型
# 1718602  5000  6.584176e+06  5.624932e+06  4.21  81  1123 21:17:56   围网
# 1718603  5000  6.583197e+06  5.624910e+06  4.10  91  1123 21:07:21   围网
# 1718604  5000  6.582123e+06  5.624777e+06  2.91  81  1123 20:57:12   围网
# 1718605  5000  6.581146e+06  5.624645e+06  3.02  71  1123 20:47:14   围网
# 1718606  5000  6.580069e+06  5.624622e+06  4.10  91  1123 20:37:17   围网

# %%
#正常的经纬度指标  x / 
plt.plot(data["x"]/50000,data['y']/200000)
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
speed_hist('刺网')

# %%
speed_hist('拖网')

# %%
speed_hist('围网')

# %%
data = pd.read_csv('train.csv')

# %%
def extract_dt(df):
    df['time'] = pd.to_datetime(df['time'], format='%m%d %H:%M:%S')
    # df['month'] = df['time'].dt.month
    # df['day'] = df['time'].dt.day
    df['date'] = df['time'].dt.date
    #得到准确时间
    df['hour_spe'] = df['time'].dt.hour+(df["time"].dt.minute)/60
    #得到小时，用于判断主要作业时段
    df["hour"] = df["time"].dt.hour
    # df = df.drop_duplicates(['ship','month'])

# %%
extract_dt(train)

# %%
def speed_hist(type_name):
    #找到相应类型的ID
    ids = train[train['type']==type_name]['ship'].unique()
    result = []
    for x in range(20):
        #随机生成渔船ID
        temp = ids[np.random.randint(len(ids))]
        result.append(temp)
    #布尔索引 找出渔船信息
    t = train[train['ship'].isin(result)]

    f, ax = plt.subplots(10,2, figsize=(8,20))
    for index, cur_id in enumerate(result):
        cur = t[t['ship']==cur_id]
        i = index//2
        j = index % 2
        ax[i,j].hist(cur['v'])
#         if i==0 and j==0:
        ax[i,j].set_title(cur_id)

# %%
def show_time(type_name):
    #找到相应类型的ID
    ids = train[train['type']==type_name]['ship'].unique()
    result = []
    for x in range(20):
        #随机生成渔船ID
        temp = ids[np.random.randint(len(ids))]
        result.append(temp)
    #布尔索引 找出渔船信息
    t = train[train['ship'].isin(result)]

    f, ax = plt.subplots(10,2, figsize=(8,20))
    for index, cur_id in enumerate(result):
        cur = t[t['ship']==cur_id]
        i = index//2
        j = index % 2
        ax[i,j].hist(cur['v'])
#         if i==0 and j==0:
        ax[i,j].set_title(cur_id)

# %%
show_time('拖网')

# %%
show_time('刺网')

# %%
show_time('围网')

# %%
def show_degree(type_name):
    #找到相应类型的ID
    ids = train[train['type']==type_name]['ship'].unique()
    result = []
    for x in range(20):
        #随机生成渔船ID
        temp = ids[np.random.randint(len(ids))]
        result.append(temp)
    #布尔索引 找出渔船信息
    t = train[train['ship'].isin(result)]

    f, ax = plt.subplots(10,2, figsize=(8,20))
    for index, cur_id in enumerate(result):
        cur = t[t['ship']==cur_id]
        i = index//2
        j = index % 2
        ax[i,j].hist(cur['g'])
#         if i==0 and j==0:
        ax[i,j].set_title(cur_id)

# %%
show_degree("围网")

# %%
show_degree("刺网")

# %%
def time_degree(type_name):
    #找到相应类型的ID
    ids = train[train['type']==type_name]['ship'].unique()
    result = []
    for x in range(20):
        #随机生成渔船ID
        temp = ids[np.random.randint(len(ids))]
        result.append(temp)
    #布尔索引 找出渔船信息
    t = train[train['ship'].isin(result)]

    f, ax = plt.subplots(10,2, figsize=(20,40))
    for index, cur_id in enumerate(result):
        cur = t[t['ship']==cur_id]
        i = index//2
        j = index % 2
        ax[i,j].polarscatter(cur["hour_spe"],cur['g'])
#         if i==0 and j==0:
        ax[i,j].set_title(cur_id)

# %%
def extract_dt(df):
    df['time'] = pd.to_datetime(df['time'], format='%m%d %H:%M:%S')
    # df['month'] = df['time'].dt.month
    # df['day'] = df['time'].dt.day
    df['date'] = df['time'].dt.date
    #得到准确时间
    df['hour_spe'] = df['time'].dt.hour+(df["time"].dt.minute)/60
    #得到小时，用于判断主要作业时段
    df["hour"] = df["time"].dt.hour
    # df = df.drop_duplicates(['ship','month'])

# %%
extract_dt(train)

# %%
time_degree('拖网')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-bccb849cc12f> in <module>
# ----> 1 time_degree('拖网')
#
# <ipython-input-40-b896073489c6> in time_degree(type_name)
#      15         i = index//2
#      16         j = index % 2
# ---> 17         ax[i,j].polarscatter(cur["hour_spe"],cur['g'])
#      18 #         if i==0 and j==0:
#      19         ax[i,j].set_title(cur_id)
#
# AttributeError: 'AxesSubplot' object has no attribute 'polarscatter'
